# %% [markdown]
# # Object Detection API Demo
#
# <table align="left"><td>
#   <a target="_blank"  href="https://colab.sandbox.google.com/github/tensorflow/models/blob/master/research/object_detection/colab_tutorials/object_detection_tutorial.ipynb">
#     <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab
#   </a>
# </td><td>
#   <a target="_blank"  href="https://github.com/tensorflow/models/blob/master/research/object_detection/colab_tutorials/object_detection_tutorial.ipynb">
#     <img width=32px src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
# </td></table>

# %% [markdown]
# Welcome to the [Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection). This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image.

# %% [markdown]
# > **Important**: This tutorial is to help you through the first step towards using [Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection) to build models. If you just just need an off the shelf model that does the job, see the [TFHub object detection example](https://colab.sandbox.google.com/github/tensorflow/hub/blob/master/examples/colab/object_detection.ipynb).

# %% [markdown]
# # Setup

# %% [markdown]
# Important: If you're running on a local machine, be sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2.md). This notebook includes only what's necessary to run in Colab.

# %% [markdown]
# ### Install

# %%
# !pip install -U --pre tensorflow=="2.*"
# !pip install tf_slim
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Collecting tensorflow==2.*
#   Using cached https://files.pythonhosted.org/packages/a7/a9/d44e012a2491cf4845b5cac79c3c3af5ab95d657c8953e9d6e076bb05f4d/tensorflow-2.1.0-cp27-cp27m-macosx_10_11_x86_64.whl
# Collecting grpcio>=1.8.6 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/bd/81/6c704c002a992b9d6466c739e3e7687e0bb2365d8cd63d7fc8e95d502cb6/grpcio-1.41.1.tar.gz (21.2MB)
#      |████████████████████████████████| 21.2MB 2.0MB/s eta 0:00:01
# Collecting gast==0.2.2 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorflow==2.*) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorflow==2.*) (1.16.5)
# Collecting scipy==1.2.2; python_version < "3" (from tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/a3/cf/36b77de4ccb1b841acd4c3c03abe38843c63c3a657cedee9e8fb19a02dc8/scipy-1.2.2-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/f6/d6/44792ec668bcda7d91913c75237314e688f70415ab2acd7172c845f0b24f/opt_einsum-2.3.2.tar.gz (59kB)
#      |████████████████████████████████| 61kB 9.0MB/s  eta 0:00:01
# Collecting tensorboard<2.2.0,>=2.1.0 (from tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/e4/c5/94a66686b86adfb3ef6f34837d0a7cc2efdc995bc39cad64a9b3e103f0d5/tensorboard-2.1.0-py2-none-any.whl
# Collecting backports.weakref>=1.0rc1; python_version < "3.4" (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting google-pasta>=0.1.6 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/59/22/38238cd9b83dd8a857abd7c907b8fe68ceff1611ab3ca5f0e80a5e025956/google_pasta-0.2.0-py2-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 12.7MB/s eta 0:00:01
# Collecting keras-applications>=1.0.8 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/21/56/4bcec5a8d9503a87e58e814c4e32ac2b32c37c685672c30bc8c54c6e478a/Keras_Applications-1.0.8.tar.gz (289kB)
#      |████████████████████████████████| 296kB 2.0MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0 (from tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: functools32>=3.2.3; python_version < "3" in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorflow==2.*) (3.2.3.post2)
# Requirement already satisfied, skipping upgrade: wheel; python_version < "3" in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorflow==2.*) (0.33.6)
# Collecting protobuf>=3.8.0 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/33/78/01ac8d2d3c2c7a3865bbf0e9ab7b6539658438af13ceeffef634a18bd022/protobuf-3.18.0rc2-py2.py3-none-any.whl (175kB)
#      |████████████████████████████████| 184kB 4.1MB/s eta 0:00:01
# Collecting absl-py>=0.7.0 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/25/d9/22a0b010487da88200c3f0672c67e892b5399b7a13d105d3863511399f6e/absl-py-0.15.0.tar.gz (114kB)
#      |████████████████████████████████| 122kB 8.3MB/s eta 0:00:01
# Collecting termcolor>=1.1.0 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorflow==2.*) (1.11.2)
# Collecting keras-preprocessing>=1.1.0 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 10.9MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: enum34>=1.1.6; python_version < "3.4" in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorflow==2.*) (1.1.6)
# Requirement already satisfied, skipping upgrade: mock>=2.0.0; python_version < "3" in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorflow==2.*) (3.0.5)
# Collecting astor>=0.6.0 (from tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: futures>=2.2.0 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from grpcio>=1.8.6->tensorflow==2.*) (3.3.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.*) (0.16.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.*) (41.4.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.*) (2.22.0)
# Collecting google-auth<2,>=1.6.3 (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/fb/7a/1b3eb54caee1b8c73c2c3645f78a382eca4805a301a30c64a078e736e446/google_auth-1.35.0-py2.py3-none-any.whl
# Collecting markdown>=2.6.8 (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 9.8MB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: h5py in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from keras-applications>=1.0.8->tensorflow==2.*) (2.9.0)
# Requirement already satisfied, skipping upgrade: funcsigs>=1; python_version < "3.3" in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from mock>=2.0.0; python_version < "3"->tensorflow==2.*) (1.0.2)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*) (2019.9.11)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*) (1.24.2)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/lib/python2.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*) (3.0.4)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/2f/a6/30b0a0bef12283e83e58c1d6e7b5aabc7acfc4110df81a4471655d33e704/cachetools-3.1.1-py2.py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl
# Collecting rsa<4.6; python_version < "3.6" (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/26/f8/8127fdda0294f044121d20aac7785feb810e159098447967a6103dedfb96/rsa-4.5-py2.py3-none-any.whl
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl
# Collecting pyasn1<0.5.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.*)
#   Using cached https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl
# Building wheels for collected packages: grpcio, gast, opt-einsum, keras-applications, absl-py, termcolor
#   Building wheel for grpcio (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/j6/242b_1p51ld6tnbm9sd5n2qh0000gp/T/pip-install-TJA9Q3/grpcio/setup.py'"'"'; __file__='"'"'/private/var/folders/j6/242b_1p51ld6tnbm9sd5n2qh0000gp/T/pip-install-TJA9Q3/grpcio/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/j6/242b_1p51ld6tnbm9sd5n2qh0000gp/T/pip-wheel-wm7K4I --python-tag cp27
#        cwd: /private/var/folders/j6/242b_1p51ld6tnbm9sd5n2qh0000gp/T/pip-install-TJA9Q3/grpcio/
#   Complete output (1859 lines):
#   Found cython-generated files...
#   running bdist_wheel
#   running build
#   running build_py
#   running build_project_metadata
#   creating python_build
#   creating python_build/lib.macosx-10.10-x86_64-2.7
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_compression.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_channel.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_common.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_utilities.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_simple_stubs.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_plugin_wrapping.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_interceptor.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_grpcio_metadata.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_server.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_runtime_protos.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   copying src/python/grpcio/grpc/_auth.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   copying src/python/grpcio/grpc/beta/_server_adaptations.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   copying src/python/grpcio/grpc/beta/interfaces.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   copying src/python/grpcio/grpc/beta/_metadata.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   copying src/python/grpcio/grpc/beta/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   copying src/python/grpcio/grpc/beta/utilities.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   copying src/python/grpcio/grpc/beta/implementations.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   copying src/python/grpcio/grpc/beta/_client_adaptations.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/beta
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/experimental
#   copying src/python/grpcio/grpc/experimental/gevent.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/experimental
#   copying src/python/grpcio/grpc/experimental/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/experimental
#   copying src/python/grpcio/grpc/experimental/session_cache.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/experimental
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework
#   copying src/python/grpcio/grpc/framework/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_base_server.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_metadata.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_typing.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_call.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_channel.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_base_channel.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_interceptor.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_server.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_base_call.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   copying src/python/grpcio/grpc/aio/_utils.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/aio
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/_cython
#   copying src/python/grpcio/grpc/_cython/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/_cython
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/experimental/aio
#   copying src/python/grpcio/grpc/experimental/aio/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/experimental/aio
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/callable_util.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/abandonment.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/stream.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/stream_util.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/future.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/logging_pool.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/foundation
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/common
#   copying src/python/grpcio/grpc/framework/common/style.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/common
#   copying src/python/grpcio/grpc/framework/common/cardinality.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/common
#   copying src/python/grpcio/grpc/framework/common/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/common
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces
#   copying src/python/grpcio/grpc/framework/interfaces/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/face
#   copying src/python/grpcio/grpc/framework/interfaces/face/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/face
#   copying src/python/grpcio/grpc/framework/interfaces/face/utilities.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/face
#   copying src/python/grpcio/grpc/framework/interfaces/face/face.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/face
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/base
#   copying src/python/grpcio/grpc/framework/interfaces/base/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/base
#   copying src/python/grpcio/grpc/framework/interfaces/base/utilities.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/base
#   copying src/python/grpcio/grpc/framework/interfaces/base/base.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/framework/interfaces/base
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/_cython/_cygrpc
#   copying src/python/grpcio/grpc/_cython/_cygrpc/__init__.py -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/_cython/_cygrpc
#   creating python_build/lib.macosx-10.10-x86_64-2.7/grpc/_cython/_credentials
#   copying src/python/grpcio/grpc/_cython/_credentials/roots.pem -> python_build/lib.macosx-10.10-x86_64-2.7/grpc/_cython/_credentials
#   running build_ext
#   Found cython-generated files...
#   building 'grpc._cython.cygrpc' extension
#   creating python_build/temp.macosx-10.10-x86_64-2.7
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/python
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/python/grpcio
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/python/grpcio/grpc
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/python/grpcio/grpc/_cython
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/census
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/health
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy/grpclb
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy/pick_first
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy/priority
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy/ring_hash
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy/round_robin
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy/weighted_target
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/lb_policy/xds
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver/dns
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver/dns/c_ares
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver/dns/native
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver/fake
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver/google_c2p
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver/sockaddr
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_channel/resolver/xds
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/client_idle
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/deadline
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/fault_injection
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/http
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/http/client
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/http/message_compress
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/http/server
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/max_age
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/message_size
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/filters/workarounds
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/alpn
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/client
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/client/insecure
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/client/secure
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/server
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/server/insecure
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/server/secure
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/chttp2/transport
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/transport/inproc
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/admin
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/admin/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/annotations
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/accesslog
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/accesslog/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/bootstrap
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/bootstrap/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/cluster
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/cluster/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/core
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/endpoint
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/endpoint/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/listener
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/listener/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/metrics
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/metrics/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/overload
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/overload/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/rbac
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/rbac/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/route
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/route/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/trace
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/config/trace/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/clusters
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/clusters/aggregate
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/clusters/aggregate/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/common
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/common/fault
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/common/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/http
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/http/fault
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/http/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/http/router
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/http/router/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/network
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/network/http_connection_manager
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/filters/network/http_connection_manager/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/transport_sockets
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/transport_sockets/tls
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/extensions/transport_sockets/tls/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/cluster
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/cluster/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/discovery
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/discovery/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/endpoint
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/endpoint/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/listener
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/listener/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/load_stats
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/load_stats/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/route
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/route/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/status
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/service/status/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/http
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/http/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/matcher
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/metadata
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/metadata/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/tracing
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/tracing/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/envoy/type/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/google
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/google/api
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/google/api/expr
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/google/api/expr/v1alpha1
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/google/protobuf
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/google/rpc
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src/proto
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src/proto/grpc
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src/proto/grpc/gcp
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src/proto/grpc/health
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src/proto/grpc/health/v1
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src/proto/grpc/lb
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/src/proto/grpc/lb/v1
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/udpa
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/udpa/annotations
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/udpa/data
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/udpa/data/orca
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/udpa/data/orca/v1
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/udpa/type
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/udpa/type/v1
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/validate
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/xds
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/xds/core
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upb-generated/xds/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/admin
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/admin/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/annotations
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/accesslog
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/accesslog/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/bootstrap
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/bootstrap/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/cluster
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/cluster/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/core
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/endpoint
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/endpoint/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/listener
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/listener/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/metrics
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/metrics/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/overload
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/overload/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/route
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/route/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/trace
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/config/trace/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/clusters
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/clusters/aggregate
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/clusters/aggregate/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/common
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/common/fault
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/common/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/http
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/fault
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/router
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/router/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/network
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/network/http_connection_manager
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/filters/network/http_connection_manager/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets/tls
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets/tls/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/cluster
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/cluster/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/discovery
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/discovery/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/endpoint
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/endpoint/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/listener
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/listener/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/load_stats
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/load_stats/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/route
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/route/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/status
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/service/status/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/http
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/http/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/matcher
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/metadata
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/metadata/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/tracing
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/tracing/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/envoy/type/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/google
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/google/api
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/google/protobuf
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/google/rpc
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/udpa
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/udpa/annotations
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/udpa/type
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/udpa/type/v1
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/validate
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/xds
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/xds/core
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/upbdefs-generated/xds/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/ext/xds
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/address_utils
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/avl
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/backoff
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/channel
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/compression
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/config
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/debug
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/event_engine
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/gpr
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/gprpp
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/http
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/iomgr
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/iomgr/event_engine
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/iomgr/executor
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/json
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/matchers
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/profiling
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/authorization
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/context
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/alts
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/composite
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/external
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/fake
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/google_default
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/iam
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/insecure
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/jwt
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/local
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/oauth2
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/plugin
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/ssl
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/tls
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/credentials/xds
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/security_connector
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/security_connector/alts
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/security_connector/fake
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/security_connector/insecure
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/security_connector/local
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/security_connector/ssl
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/security_connector/tls
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/transport
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/security/util
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/slice
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/surface
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/transport
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/lib/uri
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/plugin_registry
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi/alts
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi/alts/crypt
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi/alts/frame_protector
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi/alts/handshaker
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi/alts/zero_copy_frame_protector
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi/ssl
#   creating python_build/temp.macosx-10.10-x86_64-2.7/src/core/tsi/ssl/session_cache
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/base
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/base/internal
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/container
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/container/internal
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/debugging
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/debugging/internal
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/hash
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/hash/internal
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/numeric
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/status
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/strings
#   creating python_build/temp.macosx-10.10-x86_64-2.7/third_party/abseil-cpp/absl/strings/internal
# ...
#           ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/e_os2.h:171:11: note: previous definition is here
#   #  define OPENSSL_EXPORT extern
#             ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:66:
#   In file included from third_party/boringssl-with-bazel/src/include/openssl/digest.h:60:
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:329:13: error: typedef redefinition with different types ('int' vs 'struct crypto_threadid_st')
#   typedef int CRYPTO_THREADID;
#               ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:231:3: note: previous definition is here
#   } CRYPTO_THREADID;
#     ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:66:
#   In file included from third_party/boringssl-with-bazel/src/include/openssl/digest.h:60:
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:400:30: error: typedef redefinition with different types ('struct env_md_ctx_st' vs 'struct evp_md_ctx_st')
#   typedef struct env_md_ctx_st EVP_MD_CTX;
#                                ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ossl_typ.h:92:30: note: previous definition is here
#   typedef struct evp_md_ctx_st EVP_MD_CTX;
#                                ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:66:
#   In file included from third_party/boringssl-with-bazel/src/include/openssl/digest.h:60:
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:401:26: error: typedef redefinition with different types ('struct env_md_st' vs 'struct evp_md_st')
#   typedef struct env_md_st EVP_MD;
#                            ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ossl_typ.h:91:26: note: previous definition is here
#   typedef struct evp_md_st EVP_MD;
#                            ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:66:
#   In file included from third_party/boringssl-with-bazel/src/include/openssl/digest.h:60:
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:405:34: error: typedef redefinition with different types ('struct evp_encode_ctx_st' vs 'struct evp_Encode_Ctx_st')
#   typedef struct evp_encode_ctx_st EVP_ENCODE_CTX;
#                                    ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ossl_typ.h:100:34: note: previous definition is here
#   typedef struct evp_Encode_Ctx_st EVP_ENCODE_CTX;
#                                    ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:22:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ec.h:1125:29: error: typedef redefinition with different types ('struct ECDSA_SIG_st' vs 'struct ecdsa_sig_st')
#   typedef struct ECDSA_SIG_st ECDSA_SIG;
#                               ^
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:398:29: note: previous definition is here
#   typedef struct ecdsa_sig_st ECDSA_SIG;
#                               ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:16:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/evp.h:99:15: error: conflicting types for 'EVP_MD_meth_get_flags'
#   unsigned long EVP_MD_meth_get_flags(const EVP_MD *md);
#                 ^
#   third_party/boringssl-with-bazel/src/include/openssl/digest.h:289:25: note: previous declaration is here
#   OPENSSL_EXPORT uint32_t EVP_MD_meth_get_flags(const EVP_MD *md);
#                           ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:16:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/evp.h:116:11: warning: 'EVP_MD_FLAG_XOF' macro redefined [-Wmacro-redefined]
#   #  define EVP_MD_FLAG_XOF         0x0002
#             ^
#   third_party/boringssl-with-bazel/src/include/openssl/digest.h:217:9: note: previous definition is here
#   #define EVP_MD_FLAG_XOF 4
#           ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:16:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/evp.h:128:11: warning: 'EVP_MD_FLAG_DIGALGID_ABSENT' macro redefined [-Wmacro-redefined]
#   #  define EVP_MD_FLAG_DIGALGID_ABSENT             0x0008
#             ^
#   third_party/boringssl-with-bazel/src/include/openssl/digest.h:212:9: note: previous definition is here
#   #define EVP_MD_FLAG_DIGALGID_ABSENT 2
#           ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:16:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/evp.h:162:10: warning: 'EVP_MD_CTX_FLAG_NON_FIPS_ALLOW' macro redefined [-Wmacro-redefined]
#   # define EVP_MD_CTX_FLAG_NON_FIPS_ALLOW  0x0008/* Allow use of non FIPS
#            ^
#   third_party/boringssl-with-bazel/src/include/openssl/digest.h:298:9: note: previous definition is here
#   #define EVP_MD_CTX_FLAG_NON_FIPS_ALLOW 0
#           ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:16:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/evp.h:447:5: error: conflicting types for 'EVP_MD_size'
#   int EVP_MD_size(const EVP_MD *md);
#       ^
#   third_party/boringssl-with-bazel/src/include/openssl/digest.h:199:23: note: previous declaration is here
#   OPENSSL_EXPORT size_t EVP_MD_size(const EVP_MD *md);
#                         ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:16:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/evp.h:448:5: error: conflicting types for 'EVP_MD_block_size'
#   int EVP_MD_block_size(const EVP_MD *md);
#       ^
#   third_party/boringssl-with-bazel/src/include/openssl/digest.h:202:23: note: previous declaration is here
#   OPENSSL_EXPORT size_t EVP_MD_block_size(const EVP_MD *md);
#                         ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:16:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/evp.h:449:15: error: conflicting types for 'EVP_MD_flags'
#   unsigned long EVP_MD_flags(const EVP_MD *md);
#                 ^
#   third_party/boringssl-with-bazel/src/include/openssl/digest.h:196:25: note: previous declaration is here
#   OPENSSL_EXPORT uint32_t EVP_MD_flags(const EVP_MD *md);
#                           ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:17:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/x509.h:30:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/sha.h:39:3: error: typedef redefinition with different types ('struct SHAstate_st' vs 'struct sha_state_st')
#   } SHA_CTX;
#     ^
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:429:29: note: previous definition is here
#   typedef struct sha_state_st SHA_CTX;
#                               ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:17:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/x509.h:30:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/sha.h:56:3: error: typedef redefinition with different types ('struct SHA256state_st' vs 'struct sha256_state_st')
#   } SHA256_CTX;
#     ^
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:427:32: note: previous definition is here
#   typedef struct sha256_state_st SHA256_CTX;
#                                  ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:67:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/engine.h:24:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/ui.h:19:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/pem.h:17:
#   In file included from /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/x509.h:30:
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/sha.h:103:3: error: typedef redefinition with different types ('struct SHA512state_st' vs 'struct sha512_state_st')
#   } SHA512_CTX;
#     ^
#   third_party/boringssl-with-bazel/src/include/openssl/base.h:428:32: note: previous definition is here
#   typedef struct sha512_state_st SHA512_CTX;
#                                  ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:69:
#   third_party/boringssl-with-bazel/src/include/openssl/ex_data.h:181:48: error: too many arguments provided to function-like macro invocation
#   OPENSSL_EXPORT void CRYPTO_cleanup_all_ex_data(void);
#                                                  ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:200:10: note: macro 'CRYPTO_cleanup_all_ex_data' defined here
#   # define CRYPTO_cleanup_all_ex_data() while(0) continue
#            ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:69:
#   third_party/boringssl-with-bazel/src/include/openssl/ex_data.h:181:21: error: variable has incomplete type 'void'
#   OPENSSL_EXPORT void CRYPTO_cleanup_all_ex_data(void);
#                       ^
#   third_party/boringssl-with-bazel/src/include/openssl/ex_data.h:184:13: error: typedef redefinition with different types ('int (CRYPTO_EX_DATA *, const CRYPTO_EX_DATA *, void **, int, long, void *)' (aka 'int (struct crypto_ex_data_st *, const struct crypto_ex_data_st *, void **, int, long, void *)') vs 'int (CRYPTO_EX_DATA *, const CRYPTO_EX_DATA *, void *, int, long, void *)' (aka 'int (struct crypto_ex_data_st *, const struct crypto_ex_data_st *, void *, int, long, void *)'))
#   typedef int CRYPTO_EX_dup(CRYPTO_EX_DATA *to, const CRYPTO_EX_DATA *from,
#               ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:170:13: note: previous definition is here
#   typedef int CRYPTO_EX_dup (CRYPTO_EX_DATA *to, const CRYPTO_EX_DATA *from,
#               ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:69:
#   third_party/boringssl-with-bazel/src/include/openssl/ex_data.h:194:8: error: redefinition of 'crypto_ex_data_st'
#   struct crypto_ex_data_st {
#          ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:86:8: note: previous definition is here
#   struct crypto_ex_data_st {
#          ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:70:
#   third_party/boringssl-with-bazel/src/include/openssl/mem.h:79:22: error: expected parameter declarator
#   OPENSSL_EXPORT void *OPENSSL_malloc(size_t size);
#                        ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:118:28: note: expanded from macro 'OPENSSL_malloc'
#           CRYPTO_malloc(num, OPENSSL_FILE, OPENSSL_LINE)
#                              ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/opensslconf.h:131:24: note: expanded from macro 'OPENSSL_FILE'
#   #  define OPENSSL_FILE __FILE__
#                          ^
#   <scratch space>:18:1: note: expanded from here
#   "third_party/boringssl-with-bazel/src/include/openssl/mem.h"
#   ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:70:
#   third_party/boringssl-with-bazel/src/include/openssl/mem.h:79:22: error: expected ')'
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:118:28: note: expanded from macro 'OPENSSL_malloc'
#           CRYPTO_malloc(num, OPENSSL_FILE, OPENSSL_LINE)
#                              ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/opensslconf.h:131:24: note: expanded from macro 'OPENSSL_FILE'
#   #  define OPENSSL_FILE __FILE__
#                          ^
#   <scratch space>:18:1: note: expanded from here
#   "third_party/boringssl-with-bazel/src/include/openssl/mem.h"
#   ^
#   third_party/boringssl-with-bazel/src/include/openssl/mem.h:79:22: note: to match this '('
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:118:22: note: expanded from macro 'OPENSSL_malloc'
#           CRYPTO_malloc(num, OPENSSL_FILE, OPENSSL_LINE)
#                        ^
#   In file included from third_party/boringssl-with-bazel/src/crypto/dsa/dsa.c:70:
#   third_party/boringssl-with-bazel/src/include/openssl/mem.h:79:22: error: conflicting types for 'CRYPTO_malloc'
#   OPENSSL_EXPORT void *OPENSSL_malloc(size_t size);
#                        ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:118:9: note: expanded from macro 'OPENSSL_malloc'
#           CRYPTO_malloc(num, OPENSSL_FILE, OPENSSL_LINE)
#           ^
#   /Users/kyoungwhanmheen/opt/anaconda3/envs/py27/include/openssl/crypto.h:266:7: note: previous declaration is here
#   void *CRYPTO_malloc(size_t num, const char *file, int line);
#         ^
#   fatal error: too many errors emitted, stopping now [-ferror-limit=]
#   5 warnings and 20 errors generated.
#   ----------------------------------------
#   ERROR: Failed building wheel for grpcio
#   Running setup.py clean for grpcio
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp27-none-any.whl size=7542 sha256=ab68eda08462a3d34b0a233d4b711aba4e3e58ba2556feae5c63281696eb72b4
#   Stored in directory: /Users/kyoungwhanmheen/Library/Caches/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for opt-einsum (setup.py) ...

# %% [markdown]
# Make sure you have `pycocotools` installed

# %%
# !pip install pycocotools

# %% [markdown]
# Get `tensorflow/models` or `cd` to parent directory of the repository.

# %%
import os
import pathlib


if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models

# %% [markdown]
# Compile protobufs and install the object_detection package

# %%
# %%bash
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.

# %%
# %%bash
# cd models/research
# pip install .

# %% [markdown]
# ### Imports

# %%
# !python --version

# %%
# !conda install tensorflow

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/j6/242b_1p51ld6tnbm9sd5n2qh0000gp/T/ipykernel_8491/1383470157.py in <module>
#       4 import sys
#       5 import tarfile
# ----> 6 import tensorflow as tf
#       7 import zipfile
#       8
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# Import the object detection module.

# %%
from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

# %% [markdown]
# Patches:

# %%
# patch tf1 into `utils.ops`
utils_ops.tf = tf.compat.v1

# Patch the location of gfile
tf.gfile = tf.io.gfile

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing the path.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %% [markdown]
# ## Loader

# %%
def load_model(model_name):
  base_url = 'http://download.tensorflow.org/models/object_detection/'
  model_file = model_name + '.tar.gz'
  model_dir = tf.keras.utils.get_file(
    fname=model_name, 
    origin=base_url + model_file,
    untar=True)

  model_dir = pathlib.Path(model_dir)/"saved_model"

  model = tf.saved_model.load(str(model_dir))

  return model

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = 'models/research/object_detection/data/mscoco_label_map.pbtxt'
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# %% [markdown]
# For the sake of simplicity we will test on 2 images:

# %%
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
PATH_TO_TEST_IMAGES_DIR = pathlib.Path('models/research/object_detection/test_images')
TEST_IMAGE_PATHS = sorted(list(PATH_TO_TEST_IMAGES_DIR.glob("*.jpg")))
TEST_IMAGE_PATHS

# %% [markdown]
# # Detection

# %% [markdown]
# Load an object detection model:

# %%
model_name = 'ssd_mobilenet_v1_coco_2017_11_17'
detection_model = load_model(model_name)

# %% [markdown]
# Check the model's input signature, it expects a batch of 3-color images of type uint8:

# %%
print(detection_model.signatures['serving_default'].inputs)

# %% [markdown]
# And returns several outputs:

# %%
detection_model.signatures['serving_default'].output_dtypes

# %%
detection_model.signatures['serving_default'].output_shapes

# %% [markdown]
# Add a wrapper function to call the model, and cleanup the outputs:

# %%
def run_inference_for_single_image(model, image):
  image = np.asarray(image)
  # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
  input_tensor = tf.convert_to_tensor(image)
  # The model expects a batch of images, so add an axis with `tf.newaxis`.
  input_tensor = input_tensor[tf.newaxis,...]

  # Run inference
  model_fn = model.signatures['serving_default']
  output_dict = model_fn(input_tensor)

  # All outputs are batches tensors.
  # Convert to numpy arrays, and take index [0] to remove the batch dimension.
  # We're only interested in the first num_detections.
  num_detections = int(output_dict.pop('num_detections'))
  output_dict = {key:value[0, :num_detections].numpy() 
                 for key,value in output_dict.items()}
  output_dict['num_detections'] = num_detections

  # detection_classes should be ints.
  output_dict['detection_classes'] = output_dict['detection_classes'].astype(np.int64)
   
  # Handle models with masks:
  if 'detection_masks' in output_dict:
    # Reframe the the bbox mask to the image size.
    detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
              output_dict['detection_masks'], output_dict['detection_boxes'],
               image.shape[0], image.shape[1])      
    detection_masks_reframed = tf.cast(detection_masks_reframed > 0.5,
                                       tf.uint8)
    output_dict['detection_masks_reframed'] = detection_masks_reframed.numpy()
    
  return output_dict

# %% [markdown]
# Run it on each test image and show the results:

# %%
def show_inference(model, image_path):
  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.
  image_np = np.array(Image.open(image_path))
  # Actual detection.
  output_dict = run_inference_for_single_image(model, image_np)
  # Visualization of the results of a detection.
  vis_util.visualize_boxes_and_labels_on_image_array(
      image_np,
      output_dict['detection_boxes'],
      output_dict['detection_classes'],
      output_dict['detection_scores'],
      category_index,
      instance_masks=output_dict.get('detection_masks_reframed', None),
      use_normalized_coordinates=True,
      line_thickness=8)

  display(Image.fromarray(image_np))

# %%
for image_path in TEST_IMAGE_PATHS:
  show_inference(detection_model, image_path)

# %% [markdown]
# ## Instance Segmentation

# %%
model_name = "mask_rcnn_inception_resnet_v2_atrous_coco_2018_01_28"
masking_model = load_model(model_name)

# %% [markdown]
# The instance segmentation model includes a `detection_masks` output:

# %%
masking_model.output_shapes

# %%
for image_path in TEST_IMAGE_PATHS:
  show_inference(masking_model, image_path)
